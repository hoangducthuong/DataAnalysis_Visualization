# %% [markdown]
# # <font color='blue'> Lecture 0: Introduction to Jupyter Notebook and Python </font>
#
# *`@prepared by Hoang Duc Thuong, Department of Space and Applications, USTH.`*
# hoang-duc.thuong@usth.edu.vn
#
# Data Science is a branch of computer science where we study how to store, use and analyze data for deriving information. In this lecture, I will provide practices on:
# - JupyterLab which is the development of Jupyter Notebook. JupyterLab is a flexible interactive web-based environtment for Python programme and visualization.
# - Python and scientific computing which is the center of the lecture. I will introduce Python programming language, then I will provide overview of some useful libraries in scientific analysis and visualization: NumPy, Matplotlib, Scipy, Astropy.
#
# I also present the combination of Jupyter notebook and Hypertext Markup Language([HTML](https://www.w3schools.com/html/)) to build this web-based lecture note.

# %% [markdown]
# # Table of Contents
#
# * [1. JupyterLab](#chapter1)
#     * [1.1. General](#1p1)
#     * [1.2. Spyder (Matlab like)](#1p2)
# * [2. Python and scientific computing](#chapter2)
#     * [2.0. Python Introduction](#2p0)
#         * [Variables](#2p0p0)
#         * [Data types](#2p0p1)
#         * [Array (basic)](#2p0p2)
#         * [If ... else](#2p0p3)
#         * [Loops (while, for)](#2p0p4)
#         * [Try ... except](#2p0p5)
#         * [Function](#2p0p6)
#         * [File handling](#2p0p7)
#         * [Class](#2p0p8)
#
#     * [2.1. Numpy (array)](#2p1)
#     * [2.2. Matplotlib](#2p2)
#     * [2.3. Scipy](#2p3)
#     * [2.4. Astropy](#2p4)
# * [3. References](#chapter3)
#
#
# ***
# ***

# %% [markdown]
# # 1. JupyterLab <a class="anchor" id="chapter1"></a>
#
# It is an interactive web-based coding editor compare to [Visual studio](https://code.visualstudio.com/), [Sublime](https://www.sublimetext.com/), [Atom](https://atom.io/), [Aquamac](https://aquamacs.org/), [emacs](https://www.gnu.org/software/emacs/), [vim](https://www.vim.org/), [Spyder](https://www.spyder-ide.org/). It likes a living Ipython environment.

# %% [markdown]
# ## 1.1. General <a class="anchor" id="1p1"></a>
#
# Let's start JupyterLab form a Mac OS terminal. It is similar in a Linux system. We can start JupyterLab via Anaconda on a Windows computer. <br>
# <img src="Images/jupyterlab_start_mac.png" width=600>
# <img src="Images/labpreview.png">
# <br>

# %% [markdown]
#  - <b> Shift + Enter to run a cell. </b>
#  - **Raw**: Normal text format.
#  - **Code cells**: Edit and write code, the programming language will define the kernel
#  - **Markdown**: Documentation in a literature way, this is used to organized the structure of the document. We can also write mathematics using LaTex formalism.

# %% [markdown]
# ---
# # Headling 1
# ## Headling 2
# ### Headling 3
# #### Headling 4
# ##### Headling 5
# ###### Headling 6
#
#
#
# *italics*
#
# **Bold**
#
# ***Bold italics***
#
#
# - unorder list
# - unorder list
#
# 1. order list
# 2. order list
#
#
# > blockquote

# %% [markdown]
# - Table
# | Survey | Field | RA [$deg$] | DEC [$deg$] | Area [$deg^2$] |
# | --- | --- | --- | --- | --- |
# | EoR | COSMOS | 148.625 to 151.375 | 0.625 to 3.375 | 7.56 |
# |     | CDFS   | 51.315 to 54.785 | -29.38 to -26.22 | 10   |
# |     | HERA   | 204.175 to 207.825 | -31.58 to -28.42 | 10 |
# |     | EUCLID | 80 to 100 | -70 to -63 | 140 |
# | SFH | GAMMA09 | 129 to 141 | -1.5 to 1.5 | 36 |
# |     | GAMMA12 | 174 to 186 | -1.5 to 1.5 | 36 |
# |     | GAMMA15 | 211.5 to 223.5 | -1.5 to 1.5 | 36 |
# |     | Stripe82| -11.25 to 36 | -2 to 2 | 189 |
#
#
#
# - Type some `inline code` as: `python3 run_file.py`
# or type a block code 3 backticks
#
# ```
# Use 3 backticks for a block code:
# print("This is Jupyter Notebook tutorial")
# ```
#
#
# - Direct link to a website https://www.w3schools.com/python/default.asp
# or a hyperlink method: `[keyword](http://link)`
#  [Python tutorial w3schools](https://www.w3schools.com/python/default.asp)

# %%
from IPython.display import Image, HTML, display
display(Image('Images/data_science.png'))

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('ciFXLpPvvZo', width='100%',height=350)

# %%
from IPython.display import IFrame
IFrame('http://jupyter.org', width='100%', height=350)
# Out:
#         <iframe
#             width="100%"
#             height="350"
#             src="http://jupyter.org"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ---
# ### [HTML](https://www.w3schools.com/html/default.asp) as a website structure
#    - Text format example: <u>Underlined Words Here</u>
#    - color text `<font color='blue'> Text </font>`
#    - Embed link: `<iframe src="url" title="description">`
#    - Image: `<img src="Images/jupyterlab_start_mac.png" width=600>`
#    - Bookmark: `<a class="anchor" id="chapter1"></a>`
#    - Reference: `<a href="https://space.usth.edu.vn/">This is a link</a>`
#    - Comment: `<!-- This is a comment -->1`
#    - ...
#
#
#
#
# <!DOCTYPE html>
# <html>
#    <!-- <head>
#        <title> Page title: Space website  </title>
#    </head>
#     -->
#
# <body>
#
# <h1 style="color:red;">My First Heading</h1>
# <h2>This is heading 2</h2>
# <h3>This is heading 3</h3>
# <h4>Heading 4</h4>
# <h5>Heading 5</h5>
# <h6>Heading 6</h6>
#
# <p>This is my first paragraph.
#
# <b> Bold text </b>
#
# <strong> Important text </strong>
#
# <i> Italic text </i>
#
# <em> Emphasized text </em>
#
# <mark> Marked text </mark>
#
# <small> Smaller text </small>
#
# <del> Deleted text </del>
#
# <ins> Inserted text </ins>
#
# text <sub> Subscript text </sub>
#
# text<sup> Superscript text </sup>
#
# </p>
# </body>
# </html>

# %% [markdown]
# ---
# ### Mathermatics:
#
# Create equations using Latex
# $$y=ax^2 + bx +c$$
# $$ \partial f  = \frac{dy}{dx}. $$
#
# $$P(A \mid B) = \frac{P(B \mid A)P(A)}{P(B)}. $$
#
# or math expressions: <br>
# Maxell equations
# \begin{equation}
# t = \sqrt{x^2 + y^2 + z^2}.
# \end{equation}
#
#
# \begin{align}
# \nabla  = \frac{\partial}{\partial x} + \frac{\partial}{\partial y} + \frac{\partial}{\partial z}.
# \end{align}
#
#
# \begin{align}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}}. \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho. \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}}. \\
# \nabla \cdot \vec{\mathbf{B}} & = 0.
# \end{align}
#
#
#
# - Uniform distribution
# \begin{align}
# \text{Probability density function:} \\
# \begin{cases}
# \frac{1}{b-a}&\text{for $x\in[a,b]$} \\
# 0&\text{otherwise} \\
# \end{cases}
# \\
# \text{Cumulative distribution function:} \\
# \begin{cases}
# 0&\text{for $x<a$} \\
# \frac{x-a}{b-a}&\text{for $x\in[a,b)$} \\
# 1&\text{for $x\ge b$} \\
# \end{cases}
# \end{align}

# %% [markdown]
# ---
# ### Live plot
#
# This is the powerful function of Notebook that helps to quick debug and living output.

# %%
#%config InlineBackend.figure_format ='retina'
import matplotlib.pylab as plt

x = range(1000)
y = [i ** 2 for i in x]

plt.plot(x,y)
plt.show()

# %% [markdown]
# ---
# ### Install packages as a Terminal !

# %%
# !pip3 install pip --upgrade

# %%
# !python3 --version
# Out:
# Python 3.9.1

# %% [markdown]
# ---
# ### [Cell magic](https://nbviewer.jupyter.org/github/ipython/ipython/blob/6.x/examples/IPython%20Kernel/Cell%20Magics.ipynb) : Make a new file, view, run
#
# Cell magics are the system of command conventions.

# %% [markdown]
# `%lsmagic` : List all avalable magics. <br>
# `%matplotlib inline` : All plot in the frame of the jupyterLab, important <br>
# `%timeit` : Caculate the time execution of code <br>
# `%%writefile` : This is a very useful command to write the cell contents. <br>
# `%%script` : Run the script with argument. <br>
# `%%latex` : Latex type. <br>
# `%%html` : HTML. <br>
# `%%javascript` : Java script. <br>
# `%pwd` : Print current working directory. <br>
# `%load` : Insert code from external script. <br>
# `%run` : Excute python code.<br>
# ...

# %%
# %pwd
# Out:
# '/Users/USTH/TEACHING/SA2.7DataAnalysisandVisualization'

# %%
# %%writefile first_test.py

print("Hello Space")
# Out:
# Overwriting first_test.py

# %%
# view a file
# !cat first_test.py
# Out:
# print("Hello Space")

# %%
#run a python file
# !python3 first_test.py
# Out:
# Hello Space

# %%
#run a python file
# %run first_test.py
# Out:
# Hello Space

# %%
# %%writefile second_test.txt
#
# This is an empty test file.
# We will read this file again in python tutorials.
# Goodluck!
# ...
# Out:
# Overwriting second_test.txt

# %%
# !cat second_test.txt
# Out:
# This is an empty test file.
# We will read this file again in python tutorials.
# Goodluck!
# ...

# %% [markdown]
# #### bash script

# %%
# %%bash
# echo "hello from $BASH"
# #echo $PATH
#
# for i in {1..5}
# do echo "i is $i"
# done
# Out:
# hello from /bin/bash
# i is 1
# i is 2
# i is 3
# i is 4
# i is 5

# %% [markdown]
# ### Cython

# %%
# Cython
# !pip install cython

# %%
# %load_ext Cython

# %%
# %%cython
# def myltiply_by_2(float x):   # define a function
#     return 2.0 * x
#
# number = myltiply_by_2(15)

# %%
print(number)
# Out:
# 30.0

# %% [markdown]
# #### Fortran

# %% [raw]
# !pip3 install -U fortran-magic

# %% [raw]
# %load_ext fortranmagic

# %% [raw]
# %%fortran
# subroutine my_function(x, y, z)
# real, intent(in) :: x(:), y(:)
# real, intent(out) :: z(size(x))
# z(:) = sin(x(:) + y(:))
# end subroutine

# %% [raw]
# # Now we can use this function
# z = my_function([1, 2, 3], [4, 5, 6])

# %% [markdown]
# ### R

# %% [raw]
# # R language
# !pip3 install rpy2

# %% [raw]
# %load_ext rpy2.ipython

# %% [raw]
# ### sql

# %% [raw]
# !pip install ipython-sql

# %%
#!ls

# %%
#%load_ext sql

# %% [markdown]
# ---
#
# ### Sharing files, export to slides, pdf
#
# Share your jupyter notebook on:
# - [Google colab](https://colab.research.google.com/notebooks/intro.ipynb),
# - [GitHub](https://github.com/),
# - [nbview](https://nbviewer.jupyter.org/): Just need to put GitHub links.
#
# or export to
# - html,
# - pdf
# - asciidoc
# - ...
# <img src="Images/export.png" >

# %% [markdown]
# ---
# ### Presentation slideshow (Jupyterlab extention)
# - We can creating presentations with **Jupyter Notebook**:<br>
# `jupyter nbconvert Lec0_Intro_Notebook_and_Python.ipynb --to slides --post serve`. This command will create an `.html` file that can display as presentation.
# - RISE plugin can make a live slidesshows on **Jupyter Notebook**

# %%
# !pip3 install RISE      # or conda install -c conda-forge rise

# %% [markdown]
# Now reopen Jupyter Notebook and click the RISE Slideshow button:
#
# <img src="Images/RISE_extension.png" >
#
# - **SPACEBAR** – Goes forward a slide in the slideshow
# - **SHIFT+SPACEBAR** – Goes back a slide in the slideshow
# - **SHIFT+ENTER** – Runs the cell on the current slide
# - **DOUBLE-CLICK** – To edit a Markdown cell
# - The useful shortcuts to support presentation:
#
# <img src="Images/rise_shortcut.png" >

# %% [markdown]
# - To install [RISE on jupyterlab](https://github.com/lsst-sqre/RISE/tree/jupyterlab_extension/jupyterlab/jupyterlab_rise) <br>
# `jupyter labextension install jupyterlab_rise` <br>
#
# You probably need to install [Node.js](https://nodejs.org/en/) and npm before installation. See the discussion of this issue on the Github: https://github.com/damianavila/RISE/issues/270

# %%
# !jupyter labextension install jupyterlab_rise
# Out:
# An error occured.
# ValueError: "jupyterlab_rise" is not a valid npm package
# See the log file for details:  /var/folders/5z/m6tv7m4j725_yz1y6zswfpkh0000gn/T/jupyterlab-debug-8v6540_2.log

# %% [markdown]
# ---
#
# ## 1.2. [Spyder](https://www.spyder-ide.org/) <a class="anchor" id="1p2"></a>
#
# Spyder is a MATLAB-liked environtment. It has a windows for script and excution, ...
#
# If you like Notebook, there is an external [Notebook for Spyder](https://github.com/spyder-ide/spyder-notebook) package <br>
# `conda install spyder-notebook -c spyder-ide` <br>
# or using pip <br>
# `pip install spyder-notebook`
#
# <img src="Images/spyder.png">   <br>
#
# ---
# ---
